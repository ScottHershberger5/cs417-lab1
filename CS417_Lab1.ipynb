# %% [markdown]
# <a href="https://colab.research.google.com/github/ScottHershberger5/cs417-lab1/blob/main/CS417_Lab1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # CS 417 - Lab 1: Google Colab Introduction
#
# **1/20/20206**
#
# This notebook demonstrates basic Python concepts including:
#
# - Print statements
# - Variables
# - Basic arithmetic operations
# - String formatting

# %%
# Basic print statements
print("Welcome to Google Colab!")
print("Python makes programming fun!")
# Out:
# Welcome to Google Colab!
# Python makes programming fun!

# %%
# Working with variables

favorite_food = "sushi"

favorite_number = 5

favorite_color = "blue"

print("My favorite food is:", favorite_food)
print("My favorite number is:", favorite_number)
print("My favorite color is:", favorite_color)
# Out:
# My favorite food is: sushi
# My favorite number is: 5
# My favorite color is: blue

# %%
first_name = "Scott"
last_name = "Hershberger"

print("My full name is:", first_name + " " + last_name)
# Out:
# My full name is: Scott Hershberger
